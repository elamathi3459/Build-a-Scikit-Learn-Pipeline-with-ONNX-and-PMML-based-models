# %%
# !pip install skl2onnx
# !pip install onnxruntime
# Out:
# Requirement already satisfied: skl2onnx in c:\users\elamathi\anaconda3\lib\site-packages (1.8.0)
# Requirement already satisfied: onnxconverter-common<1.9,>=1.6.1 in c:\users\elamathi\anaconda3\lib\site-packages (from skl2onnx) (1.8.1)
# Requirement already satisfied: six in c:\users\elamathi\anaconda3\lib\site-packages (from skl2onnx) (1.15.0)
# Requirement already satisfied: scikit-learn>=0.19 in c:\users\elamathi\anaconda3\lib\site-packages (from skl2onnx) (0.24.2)
# Requirement already satisfied: protobuf in c:\users\elamathi\anaconda3\lib\site-packages (from skl2onnx) (3.15.8)
# Requirement already satisfied: scipy>=1.0 in c:\users\elamathi\anaconda3\lib\site-packages (from skl2onnx) (1.5.2)
# Requirement already satisfied: numpy>=1.15 in c:\users\elamathi\anaconda3\lib\site-packages (from skl2onnx) (1.19.2)
# Requirement already satisfied: onnx>=1.2.1 in c:\users\elamathi\anaconda3\lib\site-packages (from skl2onnx) (1.9.0)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in c:\users\elamathi\anaconda3\lib\site-packages (from onnx>=1.2.1->skl2onnx) (3.7.4.3)
# Requirement already satisfied: joblib>=0.11 in c:\users\elamathi\anaconda3\lib\site-packages (from scikit-learn>=0.19->skl2onnx) (0.17.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\elamathi\anaconda3\lib\site-packages (from scikit-learn>=0.19->skl2onnx) (2.1.0)
# WARNING: Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: C:\Users\Elamathi\anaconda3\Include\UNKNOWN
# sysconfig: C:\Users\Elamathi\anaconda3\Include
# WARNING: Additional context:
# user = False
# home = None
# root = None
# prefix = None
# WARNING: Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: C:\Users\Elamathi\anaconda3\Include\UNKNOWN
# sysconfig: C:\Users\Elamathi\anaconda3\Include
# WARNING: Additional context:
# user = False
# home = None
# root = None
# prefix = None
# Requirement already satisfied: onnxruntime in c:\users\elamathi\appdata\roaming\python\python38\site-packages (1.7.0)
# Requirement already satisfied: numpy>=1.16.6 in c:\users\elamathi\anaconda3\lib\site-packages (from onnxruntime) (1.19.2)
# Requirement already satisfied: protobuf in c:\users\elamathi\anaconda3\lib\site-packages (from onnxruntime) (3.15.8)
# Requirement already satisfied: six>=1.9 in c:\users\elamathi\anaconda3\lib\site-packages (from protobuf->onnxruntime) (1.15.0)
# WARNING: Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: C:\Users\Elamathi\anaconda3\Include\UNKNOWN
# sysconfig: C:\Users\Elamathi\anaconda3\Include
# WARNING: Additional context:
# user = False
# home = None
# root = None
# prefix = None
# WARNING: Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: C:\Users\Elamathi\anaconda3\Include\UNKNOWN
# sysconfig: C:\Users\Elamathi\anaconda3\Include
# WARNING: Additional context:
# user = False
# home = None
# root = None
# prefix = None

# %%
import os

import numpy as np
import pandas as pd


import matplotlib.pyplot as plt
# %matplotlib inline


from sklearn.datasets import load_iris

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

from sklearn.tree import DecisionTreeClassifier

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline


from skl2onnx.common.data_types import FloatTensorType
from skl2onnx import convert_sklearn

import onnxruntime as rt

from onnx.tools.net_drawer import GetPydotGraph, GetOpNodeProducer

import graphviz

# %%
iris_data = load_iris()

X = pd.DataFrame(data=iris_data.data,
                 columns=['_'.join(feature_name.split()[:2]) for feature_name in iris_data.feature_names])
y = pd.DataFrame(data=iris_data.target,
                 columns=['species'])

X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size=0.1,
                                                    stratify=y,
                                                    random_state=42)

# %%
iris_train = pd.concat([X_train,
                        y_train],
                       axis=1)
iris_train.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 29            4.7          3.2           1.6          0.2        0
# 145           6.7          3.0           5.2          2.3        2
# 8             4.4          2.9           1.4          0.2        0
# 148           6.2          3.4           5.4          2.3        2
# 25            5.0          3.0           1.6          0.2        0

# %%
iris_test = pd.concat([X_test,
                       y_test],
                      axis=1)
iris_test.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 58            6.6          2.9           4.6          1.3        1
# 134           6.1          2.6           5.6          1.4        2
# 147           6.5          3.0           5.2          2.0        2
# 69            5.6          2.5           3.9          1.1        1
# 107           7.3          2.9           6.3          1.8        2

# %%
sepal_features = [0,1]
petal_features = [2,3]

sepal_transformer = Pipeline(steps=[
    ('imputer',
     SimpleImputer(strategy='mean')),
    ('scaler',
     StandardScaler())
])

petal_transformer = Pipeline(steps=[
    ('imputer',
     SimpleImputer(strategy='median')),
    ('scaler',
     StandardScaler())
])

preprocessor = ColumnTransformer(transformers=[
    ('sepal',
     sepal_transformer,
     sepal_features),
    ('petal',
     petal_transformer,
     petal_features)
])

classifier = DecisionTreeClassifier()

# %%
pipeline = Pipeline([
    ('preprocessor',
     preprocessor),
    ('classifier',
     classifier)
])

pipeline.fit(iris_train.drop('species',axis=1),
             iris_train['species']);

# %%
print(classification_report(pipeline.predict(X_train),
                            y_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        45
#            1       1.00      1.00      1.00        45
#            2       1.00      1.00      1.00        45
#
#     accuracy                           1.00       135
#    macro avg       1.00      1.00      1.00       135
# weighted avg       1.00      1.00      1.00       135

# %%
pipeline.predict(X_test)
# Out:
# array([1, 2, 2, 1, 2, 0, 0, 0, 2, 1, 0, 2, 1, 2, 0])

# %%
y_test.values.ravel()
# Out:
# array([1, 2, 2, 1, 2, 0, 0, 0, 2, 1, 0, 2, 1, 1, 0])

# %%
print(classification_report(pipeline.predict(X_test),
                            y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         5
#            1       0.80      1.00      0.89         4
#            2       1.00      0.83      0.91         6
#
#     accuracy                           0.93        15
#    macro avg       0.93      0.94      0.93        15
# weighted avg       0.95      0.93      0.93        15

# %%
input_types = dict([(x, FloatTensorType([None, 1])) for x in X_train.columns.values])

try:
    model_onnx = convert_sklearn(pipeline,
                                 'pipeline_iris_onnx',
                                initial_types=list(input_types.items()))
except Exception as e:
    print(e)

with open("iris_pipeline.onnx", "wb") as f:
    f.write(model_onnx.SerializeToString())

# %%
inputs_onnx = {k: np.array(v).astype(np.float32)[:, np.newaxis] for k, v in X_test.to_dict(orient='list').items()}

session_onnx = rt.InferenceSession("iris_pipeline.onnx")
predict_onnx = session_onnx.run(None, inputs_onnx)
print("predict", predict_onnx[0])
# Out:
# predict [1 2 2 1 2 0 0 0 2 1 0 2 1 2 0]

# %%
pydot_graph = GetPydotGraph(model_onnx.graph,
                            name=model_onnx.graph.name,
                            rankdir="TB",
                            node_producer=GetOpNodeProducer("docstring",
                                                            color="yellow",
                                                            fillcolor="yellow",
                                                            style="filled"))

graphviz.Source(pydot_graph)
